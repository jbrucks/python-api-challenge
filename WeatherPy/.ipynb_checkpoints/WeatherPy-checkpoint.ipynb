# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import scipy.stats as st

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from key import weatherKey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build empty DataFrame to add retrieved data to
weather_df = pd.DataFrame(cities, columns =['City'])

weather_df["Lat"]= ""
weather_df["Lng"]= ""
weather_df["Max Temp"]= ""
weather_df["Humidity"]= ""
weather_df["Cloudiness"]= ""
weather_df["Wind Speed"]= ""
weather_df["Country"]= ""
weather_df["Date"]= ""

weather_df.head()
# Out:
#            City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0         sitka
# 1  punta arenas
# 2        lompoc
# 3     ust-ishim
# 4         bluff

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weatherKey}&units={units}&q="

print("Beginning Data Retrieval")
print("------------------------------------------")

# Loop through the list of cities and perform a request for data on each
for index, city in enumerate(cities):
    response = requests.get(query_url + city).json()
    try:
        weather_df.loc[index, "Lat"] = response['coord']['lat']
        weather_df.loc[index, "Lng"] = response['coord']['lon']
        weather_df.loc[index, "Max Temp"] = response['main']['temp_max']
        weather_df.loc[index, "Humidity"] = response['main']['humidity']
        weather_df.loc[index, "Cloudiness"] = response['clouds']['all']
        weather_df.loc[index, "Wind Speed"] = response['wind']['speed']
        weather_df.loc[index, "Country"] = response['sys']['country']
        weather_df.loc[index, "Date"] = response['dt']
        print(f'Processing Record {index + 1} | {city.title()}...')
    except:
        print(f'- Missing field/result... skipping city # {index + 1}, {city.title()}....')
        pass
print("------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------------
# Processing Record 1 | Sitka...
# Processing Record 2 | Punta Arenas...
# Processing Record 3 | Lompoc...
# Processing Record 4 | Ust-Ishim...
# Processing Record 5 | Bluff...
# Processing Record 6 | Arraial Do Cabo...
# Processing Record 7 | Vestmannaeyjar...
# Processing Record 8 | Chokurdakh...
# Processing Record 9 | Kodiak...
# Processing Record 10 | Ploemeur...
# Processing Record 11 | Busselton...
# Processing Record 12 | Quatre Cocos...
# Processing Record 13 | Hobart...
# Processing Record 14 | Rikitea...
# Processing Record 15 | Hermanus...
# - Missing field/result... skipping city # 16, Nguiu....
# Processing Record 17 | Kapaa...
# Processing Record 18 | Ushuaia...
# Processing Record 19 | Vaini...
# - Missing field/result... skipping city # 20, Taolanaro....
# Processing Record 21 | Albany...
# Processing Record 22 | East London...
# Processing Record 23 | Alice Springs...
# Processing Record 24 | Labuhan...
# Processing Record 25 | Capreol...
# - Missing field/result... skipping city # 26, Saleaula....
# Processing Record 27 | Prince Rupert...
# Processing Record 28 | Panjab...
# Processing Record 29 | Barrow...
# - Missing field/result... skipping city # 30, Samusu....
# Processing Record 31 | Fort Nelson...
# Processing Record 32 | Katsuura...
# Processing Record 33 | Geraldton...
# Processing Record 34 | Provideniya...
# Processing Record 35 | Mar Del Plata...
# Processing Record 36 | Churapcha...
# Processing Record 37 | Pemba...
# Processing Record 38 | Kloulklubed...
# Processing Record 39 | Katangli...
# Processing Record 40 | Dikson...
# Processing Record 41 | Bredasdorp...
# Processing Record 42 | Yellowknife...
# Processing Record 43 | Fairbanks...
# Processing Record 44 | Mataura...
# Processing Record 45 | Ilulissat...
# Processing Record 46 | Seinajoki...
# Processing Record 47 | Coihaique...
# Processing Record 48 | Esperance...
# Processing Record 49 | Bathsheba...
# - Missing field/result... skipping city # 50, Nizhneyansk....
# Processing Record 51 | Matongo...
# Processing Record 52 | Payo...
# Processing Record 53 | Jamestown...
# Processing Record 54 | Torbay...
# Processing Record 55 | Itarema...
# Processing Record 56 | Port Lincoln...
# Processing Record 57 | Tasiilaq...
# Processing Record 58 | Kaele...
# Processing Record 59 | Vila Franca Do Campo...
# Processing Record 60 | Kiama...
# Processing Record 61 | Huambo...
# - Missing field/result... skipping city # 62, Sinkat....
# Processing Record 63 | Henties Bay...
# Processing Record 64 | Shubarshi...
# Processing Record 65 | Madinat Sittah Uktubar...
# Processing Record 66 | Pisco...
# Processing Record 67 | Iacu...
# Processing Record 68 | Carnarvon...
# Processing Record 69 | Luderitz...
# Processing Record 70 | Severo-Kurilsk...
# Processing Record 71 | Shirokiy...
# Processing Record 72 | Amursk...
# Processing Record 73 | Qaanaaq...
# Processing Record 74 | Port Hedland...
# Processing Record 75 | Korla...
# Processing Record 76 | Eidsvag...
# Processing Record 77 | Rawson...
# Processing Record 78 | Fortuna...
# Processing Record 79 | Butaritari...
# Processing Record 80 | Durango...
# Processing Record 81 | Mantua...
# Processing Record 82 | Cherskiy...
# Processing Record 83 | Avera...
# Processing Record 84 | La Rioja...
# Processing Record 85 | Port Alfred...
# - Missing field/result... skipping city # 86, Barentsburg....
# Processing Record 87 | Haines Junction...
# Processing Record 88 | Longyearbyen...
# Processing Record 89 | Puerto Escondido...
# Processing Record 90 | Shimoda...
# Processing Record 91 | Nanfeng...
# Processing Record 92 | Kaiyuan...
# Processing Record 93 | Bayan...
# Processing Record 94 | Kavieng...
# Processing Record 95 | Georgetown...
# Processing Record 96 | Yanam...
# Processing Record 97 | Avarua...
# Processing Record 98 | New Norfolk...
# Processing Record 99 | Massaguet...
# Processing Record 100 | Thompson...
# Processing Record 101 | Vanavara...
# Processing Record 102 | Saldanha...
# Processing Record 103 | Cabinda...
# Processing Record 104 | Arlit...
# Processing Record 105 | Nantucket...
# Processing Record 106 | Cape Town...
# Processing Record 107 | Sarangani...
# Processing Record 108 | Cockburn Town...
# Processing Record 109 | Challapata...
# Processing Record 110 | Mahebourg...
# Processing Record 111 | Cayenne...
# Processing Record 112 | Chortomlyk...
# Processing Record 113 | Hithadhoo...
# Processing Record 114 | Calama...
# Processing Record 115 | Aklavik...
# - Missing field/result... skipping city # 116, Tsihombe....
# Processing Record 117 | Puerto Ayora...
# Processing Record 118 | Vung Tau...
# Processing Record 119 | Airai...
# Processing Record 120 | Mogadishu...
# Processing Record 121 | Lata...
# Processing Record 122 | Cidreira...
# Processing Record 123 | Huarmey...
# Processing Record 124 | Vardo...
# Processing Record 125 | Bosaso...
# - Missing field/result... skipping city # 126, Yanan....
# Processing Record 127 | Kasongo-Lunda...
# Processing Record 128 | Dunedin...
# Processing Record 129 | Inirida...
# Processing Record 130 | Omboue...
# Processing Record 131 | Upernavik...
# Processing Record 132 | Nhulunbuy...
# Processing Record 133 | San Rafael...
# Processing Record 134 | Okhotsk...
# - Missing field/result... skipping city # 135, Umzimvubu....
# Processing Record 136 | Nikolskoye...
# Processing Record 137 | Barcelos...
# Processing Record 138 | Sweetwater...
# Processing Record 139 | Hilo...
# Processing Record 140 | Atuona...
# Processing Record 141 | Bengkulu...
# Processing Record 142 | Lang Son...
# - Missing field/result... skipping city # 143, Grand River South East....
# Processing Record 144 | Saskylakh...
# Processing Record 145 | Vaniyambadi...
# Processing Record 146 | Tuktoyaktuk...
# Processing Record 147 | Sao Filipe...
# Processing Record 148 | Tabou...
# Processing Record 149 | Zalantun...
# Processing Record 150 | Bethel...
# Processing Record 151 | Najran...
# - Missing field/result... skipping city # 152, Sentyabrskiy....
# Processing Record 153 | Ballina...
# Processing Record 154 | Dharchula...
# Processing Record 155 | Kudahuvadhoo...
# Processing Record 156 | Puerto Carreno...
# Processing Record 157 | Eyl...
# Processing Record 158 | Leningradskiy...
# Processing Record 159 | Rocha...
# Processing Record 160 | Mangai...
# Processing Record 161 | Camacha...
# Processing Record 162 | Nowe Miasto Lubawskie...
# Processing Record 163 | Salmas...
# Processing Record 164 | Tunduma...
# Processing Record 165 | Viedma...
# Processing Record 166 | Alofi...
# Processing Record 167 | Abadan...
# Processing Record 168 | Yar-Sale...
# Processing Record 169 | Vostok...
# Processing Record 170 | Maragogi...
# Processing Record 171 | Anadyr...
# Processing Record 172 | Asau...
# Processing Record 173 | Badou...
# Processing Record 174 | San Cristobal...
# Processing Record 175 | Antiguo Morelos...
# Processing Record 176 | Saint-Philippe...
# Processing Record 177 | College...
# Processing Record 178 | Pangnirtung...
# Processing Record 179 | Lebu...
# Processing Record 180 | Elban...
# Processing Record 181 | Sanghar...
# Processing Record 182 | Machiques...
# - Missing field/result... skipping city # 183, Barbar....
# Processing Record 184 | Tamworth...
# Processing Record 185 | Nome...
# Processing Record 186 | Meulaboh...
# Processing Record 187 | Bukama...
# Processing Record 188 | Dmanisi...
# Processing Record 189 | Ribeira Grande...
# Processing Record 190 | Sola...
# - Missing field/result... skipping city # 191, Kamenskoye....
# Processing Record 192 | Mangrol...
# Processing Record 193 | Presidencia Roque Saenz Pena...
# Processing Record 194 | Ust-Nera...
# Processing Record 195 | Jacareacanga...
# Processing Record 196 | Baghdad...
# Processing Record 197 | Castro...
# Processing Record 198 | Agadez...
# Processing Record 199 | Lyngseidet...
# Processing Record 200 | Bima...
# Processing Record 201 | Christchurch...
# Processing Record 202 | Ahipara...
# Processing Record 203 | Tigil...
# Processing Record 204 | Weihai...
# - Missing field/result... skipping city # 205, Mys Shmidta....
# Processing Record 206 | Kondinskoye...
# Processing Record 207 | Baykalsk...
# Processing Record 208 | Placido De Castro...
# Processing Record 209 | Chihuahua...
# Processing Record 210 | Talnakh...
# Processing Record 211 | Port Hardy...
# Processing Record 212 | Cabo San Lucas...
# Processing Record 213 | Kawalu...
# Processing Record 214 | Miram Shah...
# Processing Record 215 | Yulara...
# Processing Record 216 | Clyde River...
# Processing Record 217 | Bubaque...
# Processing Record 218 | Tiksi...
# Processing Record 219 | Hollister...
# Processing Record 220 | Carnot...
# Processing Record 221 | Iqaluit...
# - Missing field/result... skipping city # 222, Aflu....
# Processing Record 223 | Gondanglegi...
# Processing Record 224 | Tsogni...
# Processing Record 225 | Lida...
# Processing Record 226 | Mende...
# Processing Record 227 | Medowie...
# Processing Record 228 | Belmonte...
# Processing Record 229 | Hirara...
# Processing Record 230 | Nanortalik...
# Processing Record 231 | Luganville...
# Processing Record 232 | Vanimo...
# Processing Record 233 | Gidam...
# Processing Record 234 | Ales...
# Processing Record 235 | Caravelas...
# Processing Record 236 | Kortkeros...
# Processing Record 237 | Kragero...
# Processing Record 238 | Severo-Yeniseyskiy...
# Processing Record 239 | Winnemucca...
# Processing Record 240 | Grootfontein...
# Processing Record 241 | Srednekolymsk...
# Processing Record 242 | Seoul...
# Processing Record 243 | Touros...
# Processing Record 244 | Flinders...
# Processing Record 245 | Bambous Virieux...
# - Missing field/result... skipping city # 246, Belushya Guba....
# Processing Record 247 | Aktash...
# Processing Record 248 | Tenkodogo...
# Processing Record 249 | Pringsewu...
# Processing Record 250 | Vestmanna...
# Processing Record 251 | Ponta Do Sol...
# Processing Record 252 | Faanui...
# Processing Record 253 | Dalvik...
# Processing Record 254 | Albion...
# Processing Record 255 | Bitung...
# Processing Record 256 | Lagoa...
# Processing Record 257 | Atar...
# Processing Record 258 | Bolotnoye...
# Processing Record 259 | Constitucion...
# Processing Record 260 | Ugoofaaru...
# Processing Record 261 | Ambilobe...
# Processing Record 262 | Fukue...
# Processing Record 263 | Dese...
# Processing Record 264 | Urengoy...
# Processing Record 265 | Kangaatsiaq...
# Processing Record 266 | Namibe...
# Processing Record 267 | Uribia...
# Processing Record 268 | Trelew...
# Processing Record 269 | Thinadhoo...
# Processing Record 270 | Birao...
# Processing Record 271 | High Level...
# - Missing field/result... skipping city # 272, Illoqqortoormiut....
# Processing Record 273 | Ibra...
# Processing Record 274 | Lazaro Cardenas...
# Processing Record 275 | Axim...
# Processing Record 276 | Yabelo...
# Processing Record 277 | Coquimbo...
# Processing Record 278 | Lasa...
# Processing Record 279 | Hauterive...
# Processing Record 280 | Iisaku...
# Processing Record 281 | Guamal...
# Processing Record 282 | Nishihara...
# Processing Record 283 | Port Elizabeth...
# Processing Record 284 | Den Helder...
# Processing Record 285 | Walvis Bay...
# Processing Record 286 | Malanje...
# Processing Record 287 | Praya...
# Processing Record 288 | Traverse City...
# Processing Record 289 | Caconda...
# Processing Record 290 | Norman Wells...
# Processing Record 291 | Mercedes...
# - Missing field/result... skipping city # 292, Attawapiskat....
# - Missing field/result... skipping city # 293, One Hundred Mile House....
# Processing Record 294 | Kalengwa...
# Processing Record 295 | Fiche...
# Processing Record 296 | Salalah...
# Processing Record 297 | Coleraine...
# Processing Record 298 | Lamu...
# Processing Record 299 | Pitimbu...
# Processing Record 300 | Kaitangata...
# Processing Record 301 | Kahului...
# Processing Record 302 | Tera...
# - Missing field/result... skipping city # 303, Yeletskiy....
# Processing Record 304 | Saint Anthony...
# Processing Record 305 | Hambantota...
# Processing Record 306 | Port Macquarie...
# Processing Record 307 | Altar...
# Processing Record 308 | Cabedelo...
# Processing Record 309 | Longhua...
# Processing Record 310 | Sheridan...
# Processing Record 311 | Alugan...
# Processing Record 312 | Lavrentiya...
# Processing Record 313 | Kankan...
# - Missing field/result... skipping city # 314, Zapotlan....
# Processing Record 315 | San Quintin...
# Processing Record 316 | Stjordalshalsen...
# Processing Record 317 | Zhuanghe...
# Processing Record 318 | Nagapattinam...
# Processing Record 319 | Mazyr...
# Processing Record 320 | Rio Gallegos...
# Processing Record 321 | Chuy...
# Processing Record 322 | Mandal...
# Processing Record 323 | Pozo Colorado...
# Processing Record 324 | Isangel...
# Processing Record 325 | Damoh...
# Processing Record 326 | Baoding...
# Processing Record 327 | Casambalangan...
# Processing Record 328 | Malatya...
# Processing Record 329 | Micheweni...
# Processing Record 330 | Mahibadhoo...
# Processing Record 331 | Parkent...
# Processing Record 332 | Kavaratti...
# Processing Record 333 | Berdigestyakh...
# Processing Record 334 | Yenotayevka...
# Processing Record 335 | Tak...
# Processing Record 336 | Marzuq...
# Processing Record 337 | Hovd...
# Processing Record 338 | San Patricio...
# Processing Record 339 | Kalmunai...
# Processing Record 340 | Samarai...
# Processing Record 341 | Talas...
# Processing Record 342 | Villarrica...
# Processing Record 343 | Gazanjyk...
# Processing Record 344 | Asfi...
# Processing Record 345 | Laguna...
# Processing Record 346 | Petatlan...
# - Missing field/result... skipping city # 347, Tlaxiaco....
# - Missing field/result... skipping city # 348, Lushunkou....
# Processing Record 349 | Olinda...
# Processing Record 350 | Souillac...
# Processing Record 351 | Bartica...
# Processing Record 352 | Aripuana...
# Processing Record 353 | Rutana...
# Processing Record 354 | Jining...
# - Missing field/result... skipping city # 355, Gurgan....
# Processing Record 356 | Cocobeach...
# Processing Record 357 | Port-Gentil...
# Processing Record 358 | Nakhon Thai...
# Processing Record 359 | Magadan...
# Processing Record 360 | Tessalit...
# Processing Record 361 | Lubbock...
# Processing Record 362 | Amapa...
# Processing Record 363 | Vila Velha...
# Processing Record 364 | Victoria...
# Processing Record 365 | Russell...
# Processing Record 366 | Klaksvik...
# - Missing field/result... skipping city # 367, Amderma....
# Processing Record 368 | Tuatapere...
# Processing Record 369 | Hamilton...
# Processing Record 370 | Roma...
# Processing Record 371 | Quang Ngai...
# Processing Record 372 | Shubarkuduk...
# - Missing field/result... skipping city # 373, Tabiauea....
# Processing Record 374 | Ostrovnoy...
# Processing Record 375 | Tucurui...
# Processing Record 376 | Pilar...
# Processing Record 377 | Kota Belud...
# Processing Record 378 | Portland...
# Processing Record 379 | Shache...
# Processing Record 380 | Khovu-Aksy...
# Processing Record 381 | Ormara...
# Processing Record 382 | Miraflores...
# Processing Record 383 | Karla...
# Processing Record 384 | Nicoya...
# Processing Record 385 | Agirish...
# Processing Record 386 | Corrente...
# Processing Record 387 | Bossangoa...
# Processing Record 388 | Narsaq...
# Processing Record 389 | Ixtapa...
# Processing Record 390 | Shetpe...
# Processing Record 391 | Cap Malheureux...
# - Missing field/result... skipping city # 392, Formoso Do Araguaia....
# Processing Record 393 | Anamur...
# Processing Record 394 | Semnan...
# Processing Record 395 | Stepnyak...
# Processing Record 396 | Codrington...
# Processing Record 397 | La Ronge...
# Processing Record 398 | North Platte...
# Processing Record 399 | Rokytne...
# Processing Record 400 | Banjar...
# Processing Record 401 | Beringovskiy...
# Processing Record 402 | Vitim...
# Processing Record 403 | Soure...
# Processing Record 404 | Sao Joao Da Barra...
# Processing Record 405 | Jurm...
# Processing Record 406 | Santa Cruz...
# Processing Record 407 | Bari Sadri...
# Processing Record 408 | Rabaul...
# Processing Record 409 | Port Blair...
# Processing Record 410 | Kaihua...
# Processing Record 411 | Canyon...
# Processing Record 412 | Hobyo...
# Processing Record 413 | Khatanga...
# Processing Record 414 | Ketchikan...
# Processing Record 415 | Yangambi...
# Processing Record 416 | Sibu...
# Processing Record 417 | Kristiinankaupunki...
# Processing Record 418 | Terme...
# Processing Record 419 | Rees...
# Processing Record 420 | Bambanglipuro...
# Processing Record 421 | Lakes Entrance...
# Processing Record 422 | Krasnoselkup...
# Processing Record 423 | Buin...
# - Missing field/result... skipping city # 424, Tapaua....
# Processing Record 425 | Umm Kaddadah...
# Processing Record 426 | Aksu...
# Processing Record 427 | Lac Du Bonnet...
# Processing Record 428 | Bolobo...
# Processing Record 429 | Soto La Marina...
# Processing Record 430 | Verkhnyaya Inta...
# Processing Record 431 | Spearfish...
# - Missing field/result... skipping city # 432, Agha Jari....
# Processing Record 433 | Chenzhou...
# Processing Record 434 | Seymchan...
# Processing Record 435 | Nikolayevka...
# Processing Record 436 | Mount Isa...
# Processing Record 437 | Groningen...
# Processing Record 438 | Dosso...
# Processing Record 439 | Rodrigues Alves...
# Processing Record 440 | Almaznyy...
# Processing Record 441 | Pevek...
# Processing Record 442 | Moerai...
# - Missing field/result... skipping city # 443, Bargal....
# Processing Record 444 | Baykit...
# Processing Record 445 | Williams Lake...
# Processing Record 446 | Saint-Joseph...
# Processing Record 447 | Olafsvik...
# Processing Record 448 | Goderich...
# Processing Record 449 | Kibondo...
# Processing Record 450 | Hasaki...
# Processing Record 451 | Alyangula...
# Processing Record 452 | Maceio...
# Processing Record 453 | Te Anau...
# Processing Record 454 | Pierre...
# Processing Record 455 | Yangjiang...
# Processing Record 456 | Road Town...
# Processing Record 457 | Pimentel...
# - Missing field/result... skipping city # 458, Turtkul....
# Processing Record 459 | Saint-Augustin...
# Processing Record 460 | Sabang...
# Processing Record 461 | General Pico...
# Processing Record 462 | Brae...
# Processing Record 463 | Plettenberg Bay...
# - Missing field/result... skipping city # 464, Matsanga....
# Processing Record 465 | Batesville...
# Processing Record 466 | Kankon...
# Processing Record 467 | Kruisfontein...
# - Missing field/result... skipping city # 468, Rungata....
# Processing Record 469 | Marawi...
# Processing Record 470 | Businga...
# Processing Record 471 | Zhezkazgan...
# - Missing field/result... skipping city # 472, Falealupo....
# Processing Record 473 | Ljubljana...
# Processing Record 474 | Manaure...
# Processing Record 475 | Saint George...
# Processing Record 476 | Veraval...
# Processing Record 477 | Lafiagi...
# Processing Record 478 | Ust-Shonosha...
# - Missing field/result... skipping city # 479, Lolua....
# Processing Record 480 | San Borja...
# Processing Record 481 | Coracora...
# - Missing field/result... skipping city # 482, Halalo....
# Processing Record 483 | Guerrero Negro...
# Processing Record 484 | Sibolga...
# Processing Record 485 | Hurghada...
# Processing Record 486 | Namatanai...
# Processing Record 487 | Wewak...
# Processing Record 488 | Cedral...
# - Missing field/result... skipping city # 489, Tumannyy....
# Processing Record 490 | Moose Factory...
# Processing Record 491 | Mackay...
# Processing Record 492 | Pitiquito...
# Processing Record 493 | Wum...
# Processing Record 494 | Singaraja...
# Processing Record 495 | Moreira Sales...
# Processing Record 496 | La Palma...
# Processing Record 497 | Pampa...
# Processing Record 498 | Mulege...
# Processing Record 499 | Santa Maria...
# - Missing field/result... skipping city # 500, Marcona....
# Processing Record 501 | Norden...
# Processing Record 502 | Nosy Varika...
# Processing Record 503 | Bansdih...
# Processing Record 504 | Kindu...
# Processing Record 505 | Benguela...
# Processing Record 506 | Wonthaggi...
# Processing Record 507 | Camaqua...
# Processing Record 508 | Moree...
# Processing Record 509 | El Dorado...
# Processing Record 510 | Sobolevo...
# Processing Record 511 | Bilibino...
# Processing Record 512 | Santiago Del Estero...
# Processing Record 513 | Chardara...
# Processing Record 514 | Callaguip...
# Processing Record 515 | Cascais...
# Processing Record 516 | Kupang...
# Processing Record 517 | Kashi...
# Processing Record 518 | Husavik...
# - Missing field/result... skipping city # 519, Ambodifototra....
# Processing Record 520 | Sur...
# Processing Record 521 | Qarchi Gak...
# Processing Record 522 | Adolfo Lopez Mateos...
# Processing Record 523 | Severodvinsk...
# - Missing field/result... skipping city # 524, Kegayli....
# Processing Record 525 | Kirakira...
# Processing Record 526 | Naze...
# Processing Record 527 | Manokwari...
# - Missing field/result... skipping city # 528, Toliary....
# Processing Record 529 | Mpika...
# Processing Record 530 | Monroe...
# Processing Record 531 | Palana...
# Processing Record 532 | Iskateley...
# Processing Record 533 | Nizhniy Baskunchak...
# Processing Record 534 | Itacare...
# Processing Record 535 | Seredka...
# Processing Record 536 | Stokmarknes...
# Processing Record 537 | Bandarbeyla...
# Processing Record 538 | Bayir...
# Processing Record 539 | Ascension...
# Processing Record 540 | Saint-Louis...
# Processing Record 541 | Bogorodskoye...
# Processing Record 542 | Okha...
# Processing Record 543 | Kibala...
# Processing Record 544 | Mbulu...
# Processing Record 545 | Sorgun...
# Processing Record 546 | Tura...
# Processing Record 547 | Tariba...
# Processing Record 548 | Merauke...
# Processing Record 549 | Pangoa...
# Processing Record 550 | Zyryanka...
# Processing Record 551 | Santa Fe...
# Processing Record 552 | Kasongo...
# Processing Record 553 | Naryan-Mar...
# - Missing field/result... skipping city # 554, Palabuhanratu....
# Processing Record 555 | Durusu...
# Processing Record 556 | Maldonado...
# Processing Record 557 | Lima...
# Processing Record 558 | Jijiga...
# Processing Record 559 | Tuxpan...
# Processing Record 560 | Broken Hill...
# Processing Record 561 | Jishou...
# Processing Record 562 | Ranong...
# Processing Record 563 | Kichera...
# Processing Record 564 | Hot Springs...
# Processing Record 565 | Tazovskiy...
# Processing Record 566 | Povoa De Varzim...
# Processing Record 567 | Luorong...
# Processing Record 568 | Port Said...
# Processing Record 569 | Kyabe...
# Processing Record 570 | Padang...
# Processing Record 571 | Miles City...
# Processing Record 572 | Aden...
# Processing Record 573 | Bairiki...
# Processing Record 574 | Nogales...
# Processing Record 575 | Richards Bay...
# Processing Record 576 | Dingle...
# Processing Record 577 | Shimanovsk...
# Processing Record 578 | Asosa...
# Processing Record 579 | Chapais...
# Processing Record 580 | Mahanoro...
# Processing Record 581 | Keetmanshoop...
# Processing Record 582 | Silistra...
# Processing Record 583 | Suntar...
# Processing Record 584 | Rockhampton...
# Processing Record 585 | Yeppoon...
# Processing Record 586 | Yerbogachen...
# - Missing field/result... skipping city # 587, Balykshi....
# Processing Record 588 | Nsanje...
# Processing Record 589 | Baturaja...
# Processing Record 590 | Kochevo...
# Processing Record 591 | Clearwater...
# Processing Record 592 | Port Hawkesbury...
# Processing Record 593 | Tamandare...
# ------------------------------------------
# Data Retrieval Complete
# ------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df['Lat'].replace('', np.nan, inplace=True)
weather_df.dropna(subset=['Lat'], inplace=True)

# %%
weather_df.count()
# Out:
# City          549
# Lat           549
# Lng           549
# Max Temp      549
# Humidity      549
# Cloudiness    549
# Wind Speed    549
# Country       549
# Date          549
# dtype: int64

# %%
weather_df
# Out:
#                 City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0              sitka  57.05 -135.33     57.2       50         90      11.41
# 1       punta arenas -53.15  -70.92     33.8       86         50       5.82
# 2             lompoc  34.64 -120.46     71.6       43          0      11.41
# 3          ust-ishim  57.69   71.17    76.35       52         45       5.57
# 4              bluff -46.60  168.33       54       79         39      11.01
# ..               ...    ...     ...      ...      ...        ...        ...
# 588         baturaja  -4.13  104.17    84.74       68         65       4.47
# 589          kochevo  59.60   54.31    69.48       58          0       2.91
# 590       clearwater  27.97   -82.8    82.99       78          1       4.47
# 591  port hawkesbury  45.62  -61.35    44.01      100         20        4.7
# 592        tamandare  -8.76   -35.1    75.69       87          5       3.58
#
#     Country        Date
# 0        US  1591757113
# 1        CL  1591757113
# 2        US  1591756927
# 3        RU  1591757113
# 4        NZ  1591757113
# ..      ...         ...
# 588      ID  1591757184
# 589      RU  1591757184
# 590      US  1591757184
# 591      CA  1591757184
# 592      BR  1591757184
#
# [549 rows x 9 columns]

# %%
weather_df.to_csv("Output/city_weather_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%

# %%
csv_path = "Output/city_weather_data.csv"
city_weather_df  = pd.read_csv(csv_path, encoding="utf-8")

# Convert column data type from object to integer
city_weather_df['Humidity'] = pd.to_numeric(city_weather_df['Humidity'])

# Sort out rows where humidity was greater than 100
humid_weather_df = city_weather_df.loc[city_weather_df['Humidity'] > 100]

# Create clean DataFrame of rows where humidity was <= 100
clean_weather_df = city_weather_df.loc[city_weather_df["Humidity"] <= 100]

# %%
#  Get the indices of cities that have humidity over 100%.
print("Potential humidity outliers: " + (humid_weather_df['Humidity']).to_string(index=True))
# Out:
# Potential humidity outliers: Series([], )

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Max Temp', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Max Temperature (6/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
ax.set_axisbelow(True)
plt.savefig("Images/latvstemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Humidity', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Humidity (6/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
ax.set_axisbelow(True)
plt.savefig("Images/latvshumidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Cloudiness', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Cloudiness (6/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
ax.set_axisbelow(True)
plt.savefig("Images/latvscloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Wind Speed', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Wind Speed (6/09/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
ax.set_axisbelow(True)
plt.savefig("Images/latvswindspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# x_axis = 
# y_axis = 

# plt.xlabel('')
# plt.ylabel('')
# correlation = st.pearsonr(x_axis, y_axis)
# print(f"The correlation between {plt.xlabel} and {plt.ylabel} is {round(correlation[0],2)}")
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
# regress_values = x_axis * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.plot(x_axis,regress_values,"r-")
# plt.scatter(x_axis, y_axis)
# plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
pd.to_numeric(clean_weather_df['Lat'])
# Out:
# 0      57.05
# 1     -53.15
# 2      34.64
# 3      57.69
# 4     -46.60
#        ...
# 544    -4.13
# 545    59.60
# 546    27.97
# 547    45.62
# 548    -8.76
# Name: Lat, Length: 549, dtype: float64

# %%
north_hemi_df = clean_weather_df.loc[clean_weather_df['Lat'] > 0]
south_hemi_df = clean_weather_df.loc[clean_weather_df['Lat'] < 0]

# %%
pd.to_numeric(north_hemi_df['Lat'])
pd.to_numeric(north_hemi_df['Max Temp'])
pd.to_numeric(north_hemi_df['Humidity'])
pd.to_numeric(north_hemi_df['Cloudiness'])
pd.to_numeric(north_hemi_df['Wind Speed'])

pd.to_numeric(south_hemi_df['Lat'])
pd.to_numeric(south_hemi_df['Max Temp'])
pd.to_numeric(south_hemi_df['Humidity'])
pd.to_numeric(south_hemi_df['Cloudiness'])
pd.to_numeric(south_hemi_df['Wind Speed'])
# Out:
# 1       5.82
# 4      11.01
# 5      19.17
# 10      9.66
# 11     12.75
#        ...
# 540    10.29
# 541    10.29
# 543     2.28
# 544     4.47
# 548     3.58
# Name: Wind Speed, Length: 181, dtype: float64

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = abs(north_hemi_df['Lat'])
y_axis = abs(north_hemi_df['Max Temp'])

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Max Temp (F) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Max Temp (F) is -0.73
# The r-squared is: 0.5256363855154352

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = abs(south_hemi_df['Lat'])
y_axis = abs(south_hemi_df['Max Temp'])

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Max Temp (F) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Max Temp (F) is -0.68
# The r-squared is: 0.46248808669675434

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = north_hemi_df['Lat']
y_axis = north_hemi_df['Humidity']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Humidity (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Humidity (%) is -0.04
# The r-squared is: 0.0016764952117192607

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = south_hemi_df['Lat']
y_axis = south_hemi_df['Humidity']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Humidity (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Humidity (%) is 0.25
# The r-squared is: 0.060744586013702376

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = north_hemi_df['Lat']
y_axis = north_hemi_df['Cloudiness']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Cloudiness (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Cloudiness (%) is 0.02
# The r-squared is: 0.0006012074688963083

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = south_hemi_df['Lat']
y_axis = south_hemi_df['Cloudiness']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Cloudiness (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Cloudiness (%) is 0.08
# The r-squared is: 0.0066083655045945525

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = north_hemi_df['Lat']
y_axis = north_hemi_df['Wind Speed']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Wind Speed (mph) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Wind Speed (mph) is 0.04
# The r-squared is: 0.0017829822355496748

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = south_hemi_df['Lat']
y_axis = south_hemi_df['Wind Speed']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Wind Speed (mph) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Wind Speed (mph) is -0.28
# The r-squared is: 0.0785940314934634

# %% [markdown]
# ##  Analysis

# %%
wind_sort = clean_weather_df.sort_values(by=['Lat'])
wind_sort
   
out_wind_sort = wind_sort.drop(480)
out_wind_sort
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 16        ushuaia -54.80  -68.30     35.60        74          75       16.11
# 1    punta arenas -53.15  -70.92     33.80        86          50        5.82
# 297  rio gallegos -51.62  -69.22     35.60        80          90       17.22
# 4           bluff -46.60  168.33     54.00        79          39       11.01
# 279    kaitangata -46.28  169.85     55.17        60          18        9.53
# ..            ...    ...     ...       ...       ...         ...         ...
# 384      khatanga  71.97  102.50     57.69        34          12       12.68
# 121     upernavik  72.79  -56.15     32.67        93          66        4.32
# 35         dikson  73.51   80.55     33.78       100         100       12.28
# 66        qaanaaq  77.48  -69.36     27.86        85           0        3.40
# 80   longyearbyen  78.22   15.64     41.00        88          40        5.82
#
#     Country        Date
# 16       AR  1591757115
# 1        CL  1591757113
# 297      AR  1591757152
# 4        NZ  1591757113
# 279      NZ  1591757150
# ..      ...         ...
# 384      RU  1591757163
# 121      GL  1591757129
# 35       RU  1591757118
# 66       GL  1591757122
# 80       SJ  1591757123
#
# [548 rows x 9 columns]

# %%
x_axis = out_wind_sort['Lat']
y_axis = out_wind_sort['Wind Speed']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Wind Speed (mph) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Wind Speed (mph) is 0.02
# The r-squared is: 0.0005493057978793271

# %% [markdown]
# 1. Appears that the strongest, and only real correlation of weather evaluated is between Latitude and Max Temperature
#
# 2. After running this for different times of the day while working on this, you get varying levels of correlation, whether that is a true correlation or not is hard to say based on it shifting so much based on time of day and between the days themselves.
#
# 3. To get any truer sense of correlation, I would imagine you would need to pull data from multiple times throughout a day, as well as to collect it over the course of a year at least.
