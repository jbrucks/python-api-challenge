# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import scipy.stats as st

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build empty DataFrame to add retrieved data to
weather_df = pd.DataFrame(cities, columns =['City'])

weather_df["Lat"]= ""
weather_df["Lng"]= ""
weather_df["Max Temp"]= ""
weather_df["Humidity"]= ""
weather_df["Cloudiness"]= ""
weather_df["Wind Speed"]= ""
weather_df["Country"]= ""
weather_df["Date"]= ""

weather_df.head()
# Out:
#             City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0     sao filipe
# 1          buala
# 2          mpika
# 3  ponta delgada
# 4          vaini

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

print("Beginning Data Retrieval")
print("------------------------------------------")

# Loop through the list of cities and perform a request for data on each
for index, city in enumerate(cities):
    response = requests.get(query_url + city).json()
    try:
        weather_df.loc[index, "Lat"] = response['coord']['lat']
        weather_df.loc[index, "Lng"] = response['coord']['lon']
        weather_df.loc[index, "Max Temp"] = response['main']['temp_max']
        weather_df.loc[index, "Humidity"] = response['main']['humidity']
        weather_df.loc[index, "Cloudiness"] = response['clouds']['all']
        weather_df.loc[index, "Wind Speed"] = response['wind']['speed']
        weather_df.loc[index, "Country"] = response['sys']['country']
        weather_df.loc[index, "Date"] = response['dt']
        print(f'Processing Record {index + 1} | {city.title()}...')
    except:
        print(f'- Missing field/result... skipping city # {index + 1}, {city.title()}....')
        pass
print("------------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------------
# Processing Record 1 | Sao Filipe...
# Processing Record 2 | Buala...
# Processing Record 3 | Mpika...
# Processing Record 4 | Ponta Delgada...
# Processing Record 5 | Vaini...
# Processing Record 6 | Nikolskoye...
# Processing Record 7 | Northam...
# Processing Record 8 | Punta Arenas...
# Processing Record 9 | Bluff...
# Processing Record 10 | Broken Hill...
# Processing Record 11 | Busselton...
# Processing Record 12 | Cabo San Lucas...
# Processing Record 13 | Saint-Philippe...
# Processing Record 14 | New Norfolk...
# Processing Record 15 | Hastings...
# Processing Record 16 | Kankon...
# Processing Record 17 | Cape Town...
# Processing Record 18 | Dikson...
# Processing Record 19 | Yellowknife...
# - Missing field/result... skipping city # 20, Barentsburg....
# - Missing field/result... skipping city # 21, Belushya Guba....
# Processing Record 22 | Vila Velha...
# Processing Record 23 | Norman Wells...
# Processing Record 24 | Rikitea...
# Processing Record 25 | Esperance...
# Processing Record 26 | Bilibino...
# Processing Record 27 | Nikolayevsk-Na-Amure...
# Processing Record 28 | Jamestown...
# Processing Record 29 | Avarua...
# Processing Record 30 | Ketchikan...
# Processing Record 31 | Kirakira...
# Processing Record 32 | Krasnoselkup...
# - Missing field/result... skipping city # 33, Mys Shmidta....
# Processing Record 34 | Kununurra...
# Processing Record 35 | Kungurtug...
# Processing Record 36 | Leningradskiy...
# Processing Record 37 | San Rafael...
# Processing Record 38 | Hilo...
# Processing Record 39 | Neiafu...
# Processing Record 40 | Keshorai Patan...
# Processing Record 41 | Barrow...
# - Missing field/result... skipping city # 42, Vaitupu....
# Processing Record 43 | Roald...
# Processing Record 44 | Bakchar...
# Processing Record 552 | Surt...
# Processing Record 553 | Itamarandiba...
# Processing Record 554 | Aras...
# Processing Record 555 | Bairiki...
# Processing Record 556 | Mogadishu...
# Processing Record 557 | Okhotsk...
# Processing Record 558 | Wattegama...
# Processing Record 559 | Idah...
# Processing Record 560 | Koltubanovskiy...
# Processing Record 561 | Sorland...
# Processing Record 562 | Jalu...
# Processing Record 563 | Shelbyville...
# Processing Record 564 | Tonantins...
# - Missing field/result... skipping city # 565, Tidore....
# Processing Record 566 | Ekibastuz...
# Processing Record 567 | Asfi...
# Processing Record 568 | Garowe...
# Processing Record 569 | Ilo...
# Processing Record 570 | Kyakhta...
# Processing Record 571 | Rorvik...
# Processing Record 572 | Tupiza...
# Processing Record 573 | Beisfjord...
# Processing Record 574 | Havelock...
# Processing Record 575 | Bulgan...
# Processing Record 576 | Hambantota...
# Processing Record 577 | Myitkyina...
# Processing Record 578 | Kahului...
# Processing Record 579 | Bundaberg...
# Processing Record 580 | Dubbo...
# Processing Record 581 | Yerbogachen...
# Processing Record 582 | Siavonga...
# Processing Record 583 | Preston...
# Processing Record 584 | Conceicao Do Araguaia...
# Processing Record 585 | Sidi Ali...
# Processing Record 586 | Catia La Mar...
# Processing Record 587 | Melito Di Porto Salvo...
# Processing Record 588 | Alice Springs...
# Processing Record 589 | Raga...
# - Missing field/result... skipping city # 590, Burica....
# Processing Record 591 | Charagua...
# Processing Record 592 | Ilheus...
# Processing Record 593 | Bridlington...
# Processing Record 594 | Limoeiro Do Ajuru...
# Processing Record 595 | Forestville...
# Processing Record 596 | High Level...
# Processing Record 597 | Pierre...
# Processing Record 598 | Bella Union...
# Processing Record 599 | Berwick...
# Processing Record 600 | Den Helder...
# Processing Record 601 | Ballina...
# Processing Record 602 | Cedar City...
# Processing Record 603 | Rio Bananal...
# Processing Record 604 | Khudumelapye...
# Processing Record 605 | Kodinsk...
# Processing Record 606 | Hervey Bay...
# Processing Record 607 | Yar-Sale...
# Processing Record 608 | Port-Cartier...
# Processing Record 609 | Grand Gaube...
# ------------------------------------------
# Data Retrieval Complete
# ------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df['Lat'].replace('', np.nan, inplace=True)
weather_df.dropna(subset=['Lat'], inplace=True)

# %%
weather_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
weather_df
# Out:
#               City    Lat     Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0       sao filipe  14.90   -24.5    74.05       80         11       4.99
# 1            buala  -8.14  159.59    81.61       78         39       7.34
# 2            mpika -11.83   31.45    56.93       69          0       5.06
# 3    ponta delgada  37.73  -25.67     60.8       87         40      19.46
# 4            vaini -21.20  -175.2       77       83         20       6.93
# ..             ...    ...     ...      ...      ...        ...        ...
# 604        kodinsk  58.69   99.18    43.66       80          6       2.82
# 605     hervey bay -25.30  152.85    48.99       58          0          4
# 606       yar-sale  66.83   70.83    34.61       91         77      12.64
# 607   port-cartier  50.03  -66.87     60.8       42         75      14.99
# 608    grand gaube -20.01   57.66       72       83         28       5.01
#
#     Country        Date
# 0        CV  1591126355
# 1        SB  1591126355
# 2        ZM  1591126355
# 3        PT  1591126355
# 4        TO  1591126355
# ..      ...         ...
# 604      RU  1591126433
# 605      AU  1591126433
# 606      RU  1591126433
# 607      CA  1591126433
# 608      MU  1591126434
#
# [563 rows x 9 columns]

# %%
weather_df.to_csv("Output/city_weather_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%

# %%
csv_path = "Output/city_weather_data.csv"
city_weather_df  = pd.read_csv(csv_path, encoding="utf-8")

# Convert column data type from object to integer
city_weather_df['Humidity'] = pd.to_numeric(city_weather_df['Humidity'])

# Sort out rows where humidity was greater than 100
humid_weather_df = city_weather_df.loc[city_weather_df['Humidity'] > 100]

# Create clean DataFrame of rows where humidity was <= 100
clean_weather_df = city_weather_df.loc[city_weather_df["Humidity"] <= 100]

# %%
#  Get the indices of cities that have humidity over 100%.
print("Potential humidity outliers: " + (humid_weather_df['Humidity']).to_string(index=True))
# Out:
# Potential humidity outliers: Series([], )

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Max Temp', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Max Temperature (6/02/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
ax.set_axisbelow(True)
plt.savefig("Images/latvstemp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Humidity', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Humidity (6/02/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
ax.set_axisbelow(True)
plt.savefig("Images/latvshumidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Cloudiness', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Cloudiness (6/02/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
ax.set_axisbelow(True)
plt.savefig("Images/latvscloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
clean_weather_df.plot(kind='scatter', x='Lat', y='Wind Speed', ax=ax, grid=True, facecolors="blue", edgecolors="black", s=40)
plt.title("City Latitude vs. Wind Speed (6/02/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
ax.set_axisbelow(True)
plt.savefig("Images/latvswindspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
x_axis = 
y_axis = 

plt.xlabel('')
plt.ylabel('')
correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between {plt.xlabel} and {plt.ylabel} is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis,regress_values,"r-")
plt.scatter(x_axis, y_axis)
plt.show()
# Out:
#   File "<ipython-input-12-dba81c524822>", line 2
#     x_axis =
#              ^
# SyntaxError: invalid syntax

# %%
# Create Northern and Southern Hemisphere DataFrames
pd.to_numeric(clean_weather_df['Lat'])
# Out:
# 0      14.90
# 1      -8.14
# 2     -11.83
# 3      37.73
# 4     -21.20
#        ...
# 558    58.69
# 559   -25.30
# 560    66.83
# 561    50.03
# 562   -20.01
# Name: Lat, Length: 563, dtype: float64

# %%
north_hemi_df = clean_weather_df.loc[clean_weather_df['Lat'] > 0]
south_hemi_df = clean_weather_df.loc[clean_weather_df['Lat'] < 0]

# %%
pd.to_numeric(north_hemi_df['Lat'])
pd.to_numeric(north_hemi_df['Max Temp'])
pd.to_numeric(north_hemi_df['Humidity'])
pd.to_numeric(north_hemi_df['Cloudiness'])
pd.to_numeric(north_hemi_df['Wind Speed'])

pd.to_numeric(south_hemi_df['Lat'])
pd.to_numeric(south_hemi_df['Max Temp'])
pd.to_numeric(south_hemi_df['Humidity'])
pd.to_numeric(south_hemi_df['Cloudiness'])
pd.to_numeric(south_hemi_df['Wind Speed'])
# Out:
# 1       7.34
# 2       5.06
# 4       6.93
# 7      23.04
# 8      10.71
#        ...
# 554    10.29
# 556     2.64
# 557     7.70
# 559     4.00
# 562     5.01
# Name: Wind Speed, Length: 196, dtype: float64

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = abs(north_hemi_df['Lat'])
y_axis = abs(north_hemi_df['Max Temp'])

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Max Temp (F) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Max Temp (F) is -0.82
# The r-squared is: 0.6697731585545111

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = abs(south_hemi_df['Lat'])
y_axis = abs(south_hemi_df['Max Temp'])

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Max Temp (F) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Max Temp (F) is -0.79
# The r-squared is: 0.620592461508641

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = north_hemi_df['Lat']
y_axis = north_hemi_df['Humidity']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Humidity (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Humidity (%) is 0.09
# The r-squared is: 0.007240589300709085

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = south_hemi_df['Lat']
y_axis = south_hemi_df['Humidity']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Humidity (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Humidity (%) is 0.07
# The r-squared is: 0.004359217029986431

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = north_hemi_df['Lat']
y_axis = north_hemi_df['Cloudiness']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Cloudiness (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Cloudiness (%) is 0.0
# The r-squared is: 1.582082329542008e-05

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = south_hemi_df['Lat']
y_axis = south_hemi_df['Cloudiness']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Cloudiness (%) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Cloudiness (%) is -0.07
# The r-squared is: 0.005149523080882146

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = north_hemi_df['Lat']
y_axis = north_hemi_df['Wind Speed']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Wind Speed (mph) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Wind Speed (mph) is 0.01
# The r-squared is: 6.368650463567541e-05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = south_hemi_df['Lat']
y_axis = south_hemi_df['Wind Speed']

correlation = st.pearsonr(x_axis, y_axis)
print(f"The correlation between Latitude and Wind Speed (mph) is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between Latitude and Wind Speed (mph) is -0.18
# The r-squared is: 0.03182554824578058
